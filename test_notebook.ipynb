# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import newton
import numpy as np
from importlib import reload
reload(newton)

start = 3
fun = lambda x: x**4

newton.optimize(start, fun)   ## Assuming your function is called `optimize`.
print(newton.optimize(2.5, np.cos))  ## Minimizing cos(x) from close-ish to one minimum.
# Out:
# 0.2091816616261754
# 3.091244503358121

# %%
print(newton.first_derivative(3, fun))
print(newton.second_derivative(3, fun))
# Out:
# 113.52100000000007
# 115.34000000000046

# %%
start = -1
fun = lambda x: (x-3)**4

print(newton.optimize(start, fun))
# Out:
# 2.940893680483414
